# %% [markdown]
# # Python API Example - Access Terminal Costs Import and Storage in Dataframe
#
# This guide is designed to provide an example of how to access the Spark API:
# - The path to your client credentials is the only input needed to run this script (just before Section 2)
# - This script has been designed to display the raw outputs of requests from the API, and then shows you how to format those outputs to enable easy reading and analysis
# - This script can be copied and pasted by customers for quick use of the API
#
# __N.B. This guide is just for Access terminal data. If you're looking for other API data products (such as contract prices, Freight routes or Netbacks), please refer to their according code example files.__

# %% [markdown]
# ### Have any questions?
#
# If you have any questions regarding our API, or need help accessing specific datasets, please contact us at:
#
# __data@sparkcommodities.com__
#
# or refer to our API website for more information about this endpoint: https://www.sparkcommodities.com/api/request/access.html

# %% [markdown]
# ## 1. Importing Data
#
# Here we define the functions that allow us to retrieve the valid credentials to access the Spark API.
#
# This section can remain unchanged for most Spark API users.

# %%
# import libraries for callin the API
import json
import os
import sys
import pandas as pd
from base64 import b64encode
from urllib.parse import urljoin
from pprint import pprint

try:
    from urllib import request, parse
    from urllib.error import HTTPError
except ImportError:
    raise RuntimeError("Python 3 required")

# %%
# defining query functions 
API_BASE_URL = "https://api.sparkcommodities.com"


def retrieve_credentials(file_path=None):
    """
    Find credentials either by reading the client_credentials file or reading
    environment variables
    """
    if file_path is None:
        client_id = os.getenv("SPARK_CLIENT_ID")
        client_secret = os.getenv("SPARK_CLIENT_SECRET")
        if not client_id or not client_secret:
            raise RuntimeError(
                "SPARK_CLIENT_ID and SPARK_CLIENT_SECRET environment vars required"
            )
    else:
        # Parse the file
        if not os.path.isfile(file_path):
            raise RuntimeError("The file {} doesn't exist".format(file_path))

        with open(file_path) as fp:
            lines = [l.replace("\n", "") for l in fp.readlines()]

        if lines[0] in ("clientId,clientSecret", "client_id,client_secret"):
            client_id, client_secret = lines[1].split(",")
        else:
            print("First line read: '{}'".format(lines[0]))
            raise RuntimeError(
                "The specified file {} doesn't look like to be a Spark API client "
                "credentials file".format(file_path)
            )

    print(">>>> Found credentials!")
    print(
        ">>>> Client_id={}****, client_secret={}****".format(
            client_id[:5], client_secret[:5]
        )
    )

    return client_id, client_secret


def do_api_post_query(uri, body, headers):
    """
    OAuth2 authentication requires a POST request with client credentials before accessing the API. 
    This POST request will return an Access Token which will be used for the API GET request.
    """
    url = urljoin(API_BASE_URL, uri)

    data = json.dumps(body).encode("utf-8")

    # HTTP POST request
    req = request.Request(url, data=data, headers=headers)
    try:
        response = request.urlopen(req)
    except HTTPError as e:
        print("HTTP Error: ", e.code)
        print(e.read())
        sys.exit(1)

    resp_content = response.read()

    # The server must return HTTP 201. Raise an error if this is not the case
    assert response.status == 201, resp_content

    # The server returned a JSON response
    content = json.loads(resp_content)

    return content


def do_api_get_query(uri, access_token):
    """
    After receiving an Access Token, we can request information from the API.
    """
    url = urljoin(API_BASE_URL, uri)

    headers = {
        "Authorization": "Bearer {}".format(access_token),
        "accept": "application/json",
    }

    print(f"Fetching {url}")

    # HTTP GET request
    req = request.Request(url, headers=headers)
    try:
        response = request.urlopen(req)
    except HTTPError as e:
        print("HTTP Error: ", e.code)
        print(e.read())
        sys.exit(1)

    resp_content = response.read()

    # The server must return HTTP 201. Raise an error if this is not the case
    assert response.status == 200, resp_content

    # The server returned a JSON response
    content = json.loads(resp_content)

    return content


def get_access_token(client_id, client_secret):
    """
    Get a new access_token. Access tokens are the thing that applications use to make
    API requests. Access tokens must be kept confidential in storage.

    # Procedure:

    Do a POST query with `grantType` and `scopes` in the body. A basic authorization
    HTTP header is required. The "Basic" HTTP authentication scheme is defined in
    RFC 7617, which transmits credentials as `clientId:clientSecret` pairs, encoded
    using base64.
    """

    # Note: for the sake of this example, we choose to use the Python urllib from the
    # standard lib. One should consider using https://requests.readthedocs.io/

    payload = "{}:{}".format(client_id, client_secret).encode()
    headers = {
        "Authorization": b64encode(payload).decode(),
        "Accept": "application/json",
        "Content-Type": "application/json",
    }
    body = {
        "grantType": "clientCredentials",
        "scopes": "read:access",
    }

    content = do_api_post_query(uri="/oauth/token/", body=body, headers=headers)

    print(
        ">>>> Successfully fetched an access token {}****, valid {} seconds.".format(
            content["accessToken"][:5], content["expiresIn"]
        )
    )

    return content["accessToken"]

# %% [markdown]
# ## N.B. Credentials
#
# Here we call the above functions, and input the file path to our credentials.
#
# N.B. You must have downloaded your client credentials CSV file before proceeding. Please refer to the API documentation if you have not dowloaded them already.  Instructions for downloading your credentials can be found here:
#
# https://api.sparkcommodities.com/redoc#section/Authentication/Create-an-Oauth2-Client

# %%
# Insert file path to your client credentials here
client_id, client_secret = retrieve_credentials(file_path="/tmp/client_credentials.csv")

# Authenticate:
access_token = get_access_token(client_id, client_secret)
# Out:
# >>>> Found credentials!
# >>>> Client_id=875f4****, client_secret=6cdf8****
# >>>> Successfully fetched an access token eyJhb****, valid 604799 seconds.

# %% [markdown]
# ## 2. Latest Price Release
#
# Here we call the latest price release and print it in a readable format. This is done using the URL:
#
# __/beta/sparkr/releases/latest/__
#
#
# We then save the entire dataset as a local variable called `latest`.

# %%
## Defining the latest release function


def fetch_latest_price_releases(access_token):
    content = do_api_get_query(
        uri="/beta/sparkr/releases/latest/", access_token=access_token
    )

    return content["data"]


## Calling that function and storing the output

latest = fetch_latest_price_releases(access_token)
# Out:
# Fetching https://api.sparkcommodities.com/beta/sparkr/releases/latest/

# %%
# Checking structure of data
latest[0]
# Out:
# {'releaseDate': '2025-01-13',
#  'terminalCode': 'grain-lng',
#  'terminalName': 'Isle of Grain',
#  'perVesselSize': {'160000': {'deliveryMonths': [{'month': '2025-02-01',
#      'costsInUsdPerMmbtu': {'total': '1.297',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.226',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.223',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.341',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.757',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.747',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-03-01',
#      'costsInUsdPerMmbtu': {'total': '1.292',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.224',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.22',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.322',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.749',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.736',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-04-01',
#      'costsInUsdPerMmbtu': {'total': '1.271',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.203',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.22',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.250',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.678',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.735',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-05-01',
#      'costsInUsdPerMmbtu': {'total': '1.304',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.237',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.362',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.792',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.733',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-06-01',
#      'costsInUsdPerMmbtu': {'total': '1.378',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.311',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.609',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.041',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.731',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-07-01',
#      'costsInUsdPerMmbtu': {'total': '1.530',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.467',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.215',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '5.120',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.562',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.721',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-08-01',
#      'costsInUsdPerMmbtu': {'total': '1.531',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.467',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.216',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '5.121',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.561',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.723',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-09-01',
#      'costsInUsdPerMmbtu': {'total': '1.388',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.321',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.642',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.073',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.732',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-10-01',
#      'costsInUsdPerMmbtu': {'total': '1.353',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.273',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.215',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.527',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.913',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.718',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-11-01',
#      'costsInUsdPerMmbtu': {'total': '1.300',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.219',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.216',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.354',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.734',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.724',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-12-01',
#      'costsInUsdPerMmbtu': {'total': '1.292',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.209',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.218',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.324',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.699',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.729',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2026-01-01',
#      'costsInUsdPerMmbtu': {'total': '1.299',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.216',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.218',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.351',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.724',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.731',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}}],
#    'assumptions': {'vesselSizeCbm': 160000, 'dischargeVolumeMmbtu': 3492366}},
#   '174000': {'deliveryMonths': [{'month': '2025-02-01',
#      'costsInUsdPerMmbtu': {'total': '1.278',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.207',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.223',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.277',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.693',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.747',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-03-01',
#      'costsInUsdPerMmbtu': {'total': '1.273',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.205',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.22',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.258',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.685',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.736',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-04-01',
#      'costsInUsdPerMmbtu': {'total': '1.254',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.186',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.22',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.193',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.621',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.735',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-05-01',
#      'costsInUsdPerMmbtu': {'total': '1.284',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.217',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.295',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.725',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.733',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-06-01',
#      'costsInUsdPerMmbtu': {'total': '1.352',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.285',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.521',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.953',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.731',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-07-01',
#      'costsInUsdPerMmbtu': {'total': '1.490',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.427',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.215',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.988',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.43',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.721',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-08-01',
#      'costsInUsdPerMmbtu': {'total': '1.491',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.427',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.216',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.989',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '1.429',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.723',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-09-01',
#      'costsInUsdPerMmbtu': {'total': '1.360',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.293',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.219',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.466',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.027',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.551',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.982',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.732',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.559',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.089',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-10-01',
#      'costsInUsdPerMmbtu': {'total': '1.330',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.25',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.215',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.450',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.836',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.718',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-11-01',
#      'costsInUsdPerMmbtu': {'total': '1.282',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.201',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.216',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.292',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.672',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.724',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-12-01',
#      'costsInUsdPerMmbtu': {'total': '1.274',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.191',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.218',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.265',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.64',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.729',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2026-01-01',
#      'costsInUsdPerMmbtu': {'total': '1.281',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.355',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.198',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.218',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.436',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.074',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '4.290',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.189',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.663',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.731',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '1.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.248',
#         'description': 'Commodity Charge'}}}}],
#    'assumptions': {'vesselSizeCbm': 174000, 'dischargeVolumeMmbtu': 3814333}}}}

# %%
# Showing available vessel sizes
print(list(latest[0]["perVesselSize"]))
# Out:
# ['160000', '174000']

# %% [markdown]
# ## Storing Data as a Dataframe
#
# Define a function to store regas costs as a Dataframe, making the data more easily readable and so that specific datasets can be indexed easily.
#
# __N.B.__ Gas in Kind, Entry Capacity and Commodity Charge cost components are only available for Premium subscribers. For Trial API users, these components are wrapped up into one variable, named `other costs`.
#
# __Want to upgrade?__ Contact data@sparkcommodities.com to find out more!

# %%
def organise_dataframe(latest):
    """
    This function sorts the API content into a dataframe. The columns available are Release Date, Terminal, Month, Vessel Size, $/MMBtu and €/MWh. 
    Essentially, this function parses the Access database using the Month, Terminal and Vessel size columns as reference.
    """
    # create columns
    data_dict = {
        'Release Date':[],
        'Terminal':[],
        'Month':[],
        'Vessel Size':[],
        'Total $/MMBtu':[],
        'Basic Slot (Berth)':[],
        'Basic Slot (Unload/Stor/Regas)':[],
        'Basic Slot (B/U/S/R)':[],
        'Additional Storage':[],
        'Additional Sendout':[],
        'Gas in Kind': [],
        'Entry Capacity':[],
        'Commodity Charge':[]
    }

    # loop for each Terminal
    for l in latest:
        sizes_available = list(latest[0]['perVesselSize'].keys())

        # loop for each available size
        for s in sizes_available:
            
            # loop for each month (in the form: YYYY-MM-DD)
            for month in range(len(l['perVesselSize'][f'{s}']['deliveryMonths'])):
                
                # assigning values to each column
                data_dict['Release Date'].append(l["releaseDate"])
                data_dict['Terminal'].append(l["terminalName"])
                data_dict['Month'].append(l['perVesselSize'][f'{s}']['deliveryMonths'][month]['month'])
                data_dict['Vessel Size'].append(s)
                data_dict['Total $/MMBtu'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["total"]))
                
                data_dict['Basic Slot (Berth)'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['basic-slot-berth']['value']))
                data_dict['Basic Slot (Unload/Stor/Regas)'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['basic-slot-unload-storage-regas']['value']))
                data_dict['Basic Slot (B/U/S/R)'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['basic-slot-berth-unload-storage-regas']['value']))
                data_dict['Additional Storage'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['additional-storage']['value']))
                data_dict['Additional Sendout'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['additional-send-out']['value']))
                data_dict['Gas in Kind'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['fuel-gas-losses-gas-in-kind']['value']))
                data_dict['Entry Capacity'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['entry-capacity']['value']))
                data_dict['Commodity Charge'].append(float(l['perVesselSize'][f'{s}']['deliveryMonths'][month]["costsInUsdPerMmbtu"]["breakdown"]['commodity-charge']['value']))
                
    
    # convert into dataframe
    df = pd.DataFrame(data_dict)
    
    df['Month'] = pd.to_datetime(df['Month'])
    df['Release Date'] = pd.to_datetime(df['Release Date'])
    
    return df

# %%
prices_df = organise_dataframe(latest)

# %%
# Example of calling specific data for a chosen terminal and vessel size

prices_df[(prices_df['Terminal'] == 'Zeebrugge') & (prices_df['Vessel Size'] == '174000')]
# Out:
#    Release Date   Terminal      Month Vessel Size  Total $/MMBtu  \
# 60   2025-01-13  Zeebrugge 2025-02-01      174000          0.441
# 61   2025-01-13  Zeebrugge 2025-03-01      174000          0.432
# 62   2025-01-13  Zeebrugge 2025-04-01      174000          0.418
# 63   2025-01-13  Zeebrugge 2025-05-01      174000          0.406
# 64   2025-01-13  Zeebrugge 2025-06-01      174000          0.401
# 65   2025-01-13  Zeebrugge 2025-07-01      174000          0.401
# 66   2025-01-13  Zeebrugge 2025-08-01      174000          0.401
# 67   2025-01-13  Zeebrugge 2025-09-01      174000          0.408
# 68   2025-01-13  Zeebrugge 2025-10-01      174000          0.420
# 69   2025-01-13  Zeebrugge 2025-11-01      174000          0.429
# 70   2025-01-13  Zeebrugge 2025-12-01      174000          0.437
# 71   2025-01-13  Zeebrugge 2026-01-01      174000          0.442
#
#     Basic Slot (Berth)  Basic Slot (Unload/Stor/Regas)  Basic Slot (B/U/S/R)  \
# 60                 0.0                             0.0                 0.167
# 61                 0.0                             0.0                 0.167
# 62                 0.0                             0.0                 0.168
# 63                 0.0                             0.0                 0.168
# 64                 0.0                             0.0                 0.168
# 65                 0.0                             0.0                 0.168
# 66                 0.0                             0.0                 0.168
# 67                 0.0                             0.0                 0.168
# 68                 0.0                             0.0                 0.168
# 69                 0.0                             0.0                 0.168
# 70                 0.0                             0.0                 0.168
# 71                 0.0                             0.0                 0.168
#
#     Additional Storage  Additional Sendout  Gas in Kind  Entry Capacity  \
# 60               0.001               0.009        0.190           0.062
# 61               0.001               0.009        0.191           0.052
# 62               0.001               0.009        0.190           0.038
# 63               0.001               0.009        0.190           0.026
# 64               0.001               0.009        0.191           0.020
# 65               0.001               0.009        0.191           0.020
# 66               0.001               0.009        0.191           0.020
# 67               0.001               0.009        0.192           0.026
# 68               0.001               0.009        0.189           0.042
# 69               0.001               0.009        0.184           0.056
# 70               0.001               0.009        0.184           0.064
# 71               0.001               0.009        0.183           0.070
#
#     Commodity Charge
# 60             0.012
# 61             0.012
# 62             0.012
# 63             0.012
# 64             0.012
# 65             0.012
# 66             0.012
# 67             0.012
# 68             0.011
# 69             0.011
# 70             0.011
# 71             0.011

# %% [markdown]
# ## 3. Historical Prices
#
# Here we perform a similar task, but with historical prices instead. This is done using the URL:
#
# __/beta/sparkr/releases/{limit}{offset}__
#
# First we define the function that imports the data from the Spark API.
#
# We then call that function, and define 2 parameters:
# - `limit`: this allows you to control how many datapoints you want to call. Here we use `limit=3`, which means we have called the last 3 datapoints (Terminal price data for the last 3 business days).
#     - For __Premium__ Users, alter this limit to however many datapoints you need.
#     - For __Trial__ Users, the limit must be lesser than or equal to 14, as historical data is limited to the latest 2 weeks for this plan.
#     - The default is set as 4 (in the first line of the function). If the limit parameter is not defined, this value will be used.
# - `offset`: This parameter is optional, and the default value is None. Input how many business days you would like to offset the data
#     - for example, `offset=2` gets terminal data from 2 business days ago.
#     - __Note: Trial Users must make sure that the offset parameter in combination with the limit parameter must not exceed 14 days of the last 2 weeks.__
#
#
# We save the output as a local variable called `historical`.

# %%
## Defining the function


def fetch_price_releases(access_token, limit=4, offset=None):
    query_params = "?limit={}".format(limit)
    if offset is not None:
        query_params += "&offset={}".format(offset)

    content = do_api_get_query(
        uri="/beta/sparkr/releases/{}".format(query_params), access_token=access_token
    )

    return content["data"]


## Calling that function and storing the output

historical = fetch_price_releases(access_token, limit=3)
# Out:
# Fetching https://api.sparkcommodities.com/beta/sparkr/releases/?limit=3

# %%
# checking raw data structure
historical[0]
# Out:
# {'releaseDate': '2024-10-16',
#  'terminalCode': 'eems-energy-terminal',
#  'terminalName': 'EemsEnergyTerminal',
#  'perVesselSize': {'160000': {'deliveryMonths': [{'month': '2024-11-01',
#      'costsInUsdPerMmbtu': {'total': '0.816',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.555',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.114',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.147',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.558',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.741',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.356',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.461',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2024-12-01',
#      'costsInUsdPerMmbtu': {'total': '0.871',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.555',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.115',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.201',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.732',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.741',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.361',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.63',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-01-01',
#      'costsInUsdPerMmbtu': {'total': '0.969',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.116',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.29',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '3.039',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.364',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.911',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-02-01',
#      'costsInUsdPerMmbtu': {'total': '0.914',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.117',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.234',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.865',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.366',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.735',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-03-01',
#      'costsInUsdPerMmbtu': {'total': '0.882',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.116',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.203',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.765',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.364',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.637',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-04-01',
#      'costsInUsdPerMmbtu': {'total': '0.822',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.113',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.146',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.576',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.353',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-05-01',
#      'costsInUsdPerMmbtu': {'total': '0.801',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.562',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.105',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.134',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.514',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.763',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.33',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.421',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-06-01',
#      'costsInUsdPerMmbtu': {'total': '0.756',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.086',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.109',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.374',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.342',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-07-01',
#      'costsInUsdPerMmbtu': {'total': '0.754',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.106',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.365',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.333',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-08-01',
#      'costsInUsdPerMmbtu': {'total': '0.749',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.101',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.349',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.317',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-09-01',
#      'costsInUsdPerMmbtu': {'total': '0.757',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.109',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.375',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.273',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.341',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-10-01',
#      'costsInUsdPerMmbtu': {'total': '0.791',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.562',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.1',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.129',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.479',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.762',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.313',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.404',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}}],
#    'assumptions': {'vesselSizeCbm': 160000, 'dischargeVolumeMmbtu': 3492366}},
#   '174000': {'deliveryMonths': [{'month': '2024-11-01',
#      'costsInUsdPerMmbtu': {'total': '0.816',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.555',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.114',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.147',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.558',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.741',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.356',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.461',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2024-12-01',
#      'costsInUsdPerMmbtu': {'total': '0.871',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.555',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.115',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.201',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.732',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.741',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.361',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.63',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-01-01',
#      'costsInUsdPerMmbtu': {'total': '0.969',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.116',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.29',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '3.039',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.364',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.911',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-02-01',
#      'costsInUsdPerMmbtu': {'total': '0.914',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.117',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.234',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.865',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.366',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.735',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-03-01',
#      'costsInUsdPerMmbtu': {'total': '0.882',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.116',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.203',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.765',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.364',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.637',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-04-01',
#      'costsInUsdPerMmbtu': {'total': '0.822',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.563',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.113',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.146',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.576',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.764',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.353',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.459',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-05-01',
#      'costsInUsdPerMmbtu': {'total': '0.801',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.562',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.105',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.134',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.514',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.763',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.33',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.421',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-06-01',
#      'costsInUsdPerMmbtu': {'total': '0.756',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.086',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.109',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.374',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.342',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-07-01',
#      'costsInUsdPerMmbtu': {'total': '0.754',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.106',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.365',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.333',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-08-01',
#      'costsInUsdPerMmbtu': {'total': '0.749',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.101',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.349',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.271',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.317',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-09-01',
#      'costsInUsdPerMmbtu': {'total': '0.757',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.561',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.087',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.109',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.375',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.761',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.273',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.341',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}},
#     {'month': '2025-10-01',
#      'costsInUsdPerMmbtu': {'total': '0.791',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '0.562',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.1',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.129',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}},
#      'costsInEurPerMwh': {'total': '2.479',
#       'breakdown': {'basic-slot-berth': {'type': 'basic-slot-berth',
#         'value': '0.0',
#         'description': 'Slot (Berth)'},
#        'basic-slot-unload-storage-regas': {'type': 'basic-slot-unload-storage-regas',
#         'value': '0.0',
#         'description': 'Slot (Unload, Storage, Regas)'},
#        'basic-slot-berth-unload-storage-regas': {'type': 'basic-slot-berth-unload-storage-regas',
#         'value': '1.762',
#         'description': 'Slot (Berth, Unload, Storage, Regas)'},
#        'additional-storage': {'type': 'additional-storage',
#         'value': '0.0',
#         'description': 'Additional Storage'},
#        'additional-send-out': {'type': 'additional-send-out',
#         'value': '0.0',
#         'description': 'Additional Send Out'},
#        'fuel-gas-losses-gas-in-kind': {'type': 'fuel-gas-losses-gas-in-kind',
#         'value': '0.313',
#         'description': 'Fuel Gas Losses (Gas in Kind)'},
#        'entry-capacity': {'type': 'entry-capacity',
#         'value': '0.404',
#         'description': 'Entry Capacity'},
#        'commodity-charge': {'type': 'commodity-charge',
#         'value': '0.0',
#         'description': 'Commodity Charge'}}}}],
#    'assumptions': {'vesselSizeCbm': 174000, 'dischargeVolumeMmbtu': 3814333}}}}

# %% [markdown]
# ### Storing as a DataFrame
# We can reuse our `organise_dataframe` function to parse the content into a dataframe

# %%
# running function
hist_df = organise_dataframe(historical)

# %%
hist_df
# Out:
#      Release Date            Terminal      Month Vessel Size  Total $/MMBtu  \
# 0      2024-10-16  EemsEnergyTerminal 2024-11-01      160000          0.816
# 1      2024-10-16  EemsEnergyTerminal 2024-12-01      160000          0.871
# 2      2024-10-16  EemsEnergyTerminal 2025-01-01      160000          0.969
# 3      2024-10-16  EemsEnergyTerminal 2025-02-01      160000          0.914
# 4      2024-10-16  EemsEnergyTerminal 2025-03-01      160000          0.882
# ...           ...                 ...        ...         ...            ...
# 1369   2024-10-14           Spain TVB 2025-06-01      174000          0.265
# 1370   2024-10-14           Spain TVB 2025-07-01      174000          0.265
# 1371   2024-10-14           Spain TVB 2025-08-01      174000          0.265
# 1372   2024-10-14           Spain TVB 2025-09-01      174000          0.265
# 1373   2024-10-14           Spain TVB 2025-10-01      174000          0.256
#
#       Basic Slot (Berth)  Basic Slot (Unload/Stor/Regas)  \
# 0                  0.000                           0.000
# 1                  0.000                           0.000
# 2                  0.000                           0.000
# 3                  0.000                           0.000
# 4                  0.000                           0.000
# ...                  ...                             ...
# 1369               0.009                           0.094
# 1370               0.009                           0.094
# 1371               0.009                           0.094
# 1372               0.009                           0.094
# 1373               0.009                           0.099
#
#       Basic Slot (B/U/S/R)  Additional Storage  Additional Sendout  \
# 0                    0.555               0.000                 0.0
# 1                    0.555               0.000                 0.0
# 2                    0.563               0.000                 0.0
# 3                    0.563               0.000                 0.0
# 4                    0.563               0.000                 0.0
# ...                    ...                 ...                 ...
# 1369                 0.000               0.003                 0.0
# 1370                 0.000               0.003                 0.0
# 1371                 0.000               0.003                 0.0
# 1372                 0.000               0.003                 0.0
# 1373                 0.000               0.003                 0.0
#
#       Gas in Kind  Entry Capacity  Commodity Charge
# 0           0.114           0.147             0.000
# 1           0.115           0.201             0.000
# 2           0.116           0.290             0.000
# 3           0.117           0.234             0.000
# 4           0.116           0.203             0.000
# ...           ...             ...               ...
# 1369        0.000           0.115             0.044
# 1370        0.000           0.115             0.044
# 1371        0.000           0.115             0.044
# 1372        0.000           0.115             0.044
# 1373        0.000           0.101             0.044
#
# [1374 rows x 13 columns]

# %% [markdown]
# ## N.B. Historical Data Limits
#
# Currently, a maximum of 20 historical datasets can be called at one time due to the size of the data file.
#
# If more data points are required, the below code can be used. It calls 20 historical datasets at a time, but utilises the `offset` parameter to call datasets further back in the historical database. To call more history, increase the `n_offset` parameter in the first line of the code. The `n_offset` parameter describes the number of historical data requests to be executed.
#
# ### Access Premium Plan
#
# Premium users have full access to historical data.

# %%
def loop_historical_data(token,n_offset):
    # initalise first set of historical data and initialising dataframe
    historical = fetch_price_releases(access_token=token,limit=20)
    hist_df = organise_dataframe(historical)

    # Looping through earlier historical data and adding to the historical dataframe
    for i in range(1,n_offset+1):
        historical = fetch_price_releases(access_token=token,limit=20,offset=i*20)
        hist_df = pd.concat([hist_df,organise_dataframe(historical)])

    return hist_df

# %% [markdown]
# ### Access Trial Plan
#
# Trial users are limited to the latest 2 weeks' worth of data. To call this history, the following function can be executed.

# %%
def trial_historical_data(token):
    # initalise first set of historical data and initialising dataframe
    historical = fetch_price_releases(access_token=token,limit=10)
    hist_df = organise_dataframe(historical)

    return hist_df
