# %% [markdown]
# # Python API Example - Arb Breakevens Data Import and Storage in Dataframe
#
# This guide is designed to provide an example of how to call the Arb Breakevens API endpoint, and store the data accordingly.
#
# __N.B. This guide is just for Arb Breakevens data. If you're looking for other API data products (such as Netbacks, Price releases or Freight routes), please refer to their according code example files.__

# %% [markdown]
# ### Have any questions?
#
# If you have any questions regarding our API, or need help accessing specific datasets, please contact us at:
#
# __data@sparkcommodities.com__

# %% [markdown]
# ## 1. Importing Data
#
# Here we define the functions that allow us to retrieve the valid credentials to access the Spark API.
#
# __This section can remain unchanged for most Spark API users.__

# %%
# Importing libraries for calling the API
import json
import os
import sys
import pandas as pd
from base64 import b64encode
from urllib.parse import urljoin


try:
    from urllib import request, parse
    from urllib.error import HTTPError
except ImportError:
    raise RuntimeError("Python 3 required")

# %%
# Defining functions for API request

API_BASE_URL = "https://api.sparkcommodities.com"


def retrieve_credentials(file_path=None):
    """
    Find credentials either by reading the client_credentials file or reading
    environment variables
    """
    if file_path is None:
        client_id = os.getenv("SPARK_CLIENT_ID")
        client_secret = os.getenv("SPARK_CLIENT_SECRET")
        if not client_id or not client_secret:
            raise RuntimeError(
                "SPARK_CLIENT_ID and SPARK_CLIENT_SECRET environment vars required"
            )
    else:
        # Parse the file
        if not os.path.isfile(file_path):
            raise RuntimeError("The file {} doesn't exist".format(file_path))

        with open(file_path) as fp:
            lines = [l.replace("\n", "") for l in fp.readlines()]

        if lines[0] in ("clientId,clientSecret", "client_id,client_secret"):
            client_id, client_secret = lines[1].split(",")
        else:
            print("First line read: '{}'".format(lines[0]))
            raise RuntimeError(
                "The specified file {} doesn't look like to be a Spark API client "
                "credentials file".format(file_path)
            )

    print(">>>> Found credentials!")
    print(
        ">>>> Client_id={}, client_secret={}****".format(client_id, client_secret[:5])
    )

    return client_id, client_secret


def do_api_post_query(uri, body, headers):
    """
    OAuth2 authentication requires a POST request with client credentials before accessing the API. 
    This POST request will return an Access Token which will be used for the API GET request.
    """
    url = urljoin(API_BASE_URL, uri)

    data = json.dumps(body).encode("utf-8")

    # HTTP POST request
    req = request.Request(url, data=data, headers=headers)
    try:
        response = request.urlopen(req)
    except HTTPError as e:
        print("HTTP Error: ", e.code)
        print(e.read())
        sys.exit(1)

    resp_content = response.read()

    # The server must return HTTP 201. Raise an error if this is not the case
    assert response.status == 201, resp_content

    # The server returned a JSON response
    content = json.loads(resp_content)

    return content


def do_api_get_query(uri, access_token, format='json'):
    """
    After receiving an Access Token, we can request information from the API.
    """
    url = urljoin(API_BASE_URL, uri)

    if format == 'json':
        headers = {
            "Authorization": "Bearer {}".format(access_token),
            "Accept": "application/json",
        }
    elif format == 'csv':
        headers = {
            "Authorization": "Bearer {}".format(access_token),
            "Accept": "text/csv"
        }

    #headers = {
    #    "Authorization": "Bearer {}".format(access_token),
    #    "Accept": "application/json",
    #}

    # HTTP POST request
    req = request.Request(url, headers=headers)
    try:
        response = request.urlopen(req)
    except HTTPError as e:
        print("HTTP Error: ", e.code)
        print(e.read())
        sys.exit(1)

    resp_content = response.read()

    # The server must return HTTP 201. Raise an error if this is not the case
    assert response.status == 200, resp_content

    # Storing response based on requested format
    if format == 'json':
        content = json.loads(resp_content)
    elif format == 'csv':
        content = resp_content

    return content


def get_access_token(client_id, client_secret):
    """
    Get a new access_token. Access tokens are the thing that applications use to make
    API requests. Access tokens must be kept confidential in storage.

    # Procedure:

    Do a POST query with `grantType` and `scopes` in the body. A basic authorization
    HTTP header is required. The "Basic" HTTP authentication scheme is defined in
    RFC 7617, which transmits credentials as `clientId:clientSecret` pairs, encoded
    using base64.
    """

    # Note: for the sake of this example, we choose to use the Python urllib from the
    # standard lib. One should consider using https://requests.readthedocs.io/

    payload = "{}:{}".format(client_id, client_secret).encode()
    headers = {
        "Authorization": b64encode(payload).decode(),
        "Accept": "application/json",
        "Content-Type": "application/json",
    }
    body = {
        "grantType": "clientCredentials",
        "scopes": "read:netbacks,read:access,read:prices,read:routes",
    }

    content = do_api_post_query(uri="/oauth/token/", body=body, headers=headers)

    print(
        ">>>> Successfully fetched an access token {}****, valid {} seconds.".format(
            content["accessToken"][:5], content["expiresIn"]
        )
    )

    return content["accessToken"]

# %% [markdown]
# ## Reference Data fetching
#
# In the fetch request, we use the URL:
#
# __uri="/v1.0/netbacks/reference-data/"__
#
# This query shows an overview on all available netbacks and according arb breakevens, showing all available ports and possible routes to/from these destinations (i.e. via Suez, Panama etc.).

# %%
# Define the function for listing all netbacks
def list_netbacks(access_token):
    """
    Fetch available routes. Return contract ticker symbols

    # Procedure:

    Do a GET query to /v1.0/routes/ with a Bearer token authorization HTTP header.
    """
    content = do_api_get_query(
        uri="/v1.0/netbacks/reference-data/", access_token=access_token
    )

    print(">>>> All the routes you can fetch")
    tickers = []
    fobPort_names = []

    availablevia = []

    for contract in content["data"]["staticData"]["fobPorts"]:
        tickers.append(contract["uuid"])
        fobPort_names.append(contract["name"])

        availablevia.append(contract["availableViaPoints"])

    reldates = content["data"]["staticData"]["sparkReleases"]

    dicto1 = content["data"]

    return tickers, fobPort_names, availablevia, reldates, dicto1

# %% [markdown]
# ## N.B. Credentials
#
# Here we call the above functions, and input the file path to our credentials.
#
# N.B. You must have downloaded your client credentials CSV file before proceeding. Please refer to the API documentation if you have not dowloaded them already.  Instructions for downloading your credentials can be found here:
#
# https://api.sparkcommodities.com/redoc#section/Authentication/Create-an-Oauth2-Client

# %%
# Input the path to your client credentials here
client_id, client_secret = retrieve_credentials(file_path="/tmp/client_credentials.csv")

# Authenticate:
access_token = get_access_token(client_id, client_secret)
print(access_token)

# Fetch all contracts:
tickers, fobPort_names, availablevia, reldates, dicto1 = list_netbacks(access_token)
# Out:
# >>>> Found credentials!
# >>>> Client_id=01c23590-ef6c-4a36-8237-c89c3f1a3b2a, client_secret=80763****
# >>>> Successfully fetched an access token eyJhb****, valid 604799 seconds.
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..f65SrH9FbI8DqkAfclLHftUXS6U7fqbmz77996ZZVQ0
# >>>> All the routes you can fetch

# %%
# Prints the callable route options, corresponding to each Route ID number shown above
# I.e. availablevia[2] shows the available route options for tickers[2]

print(availablevia)
# Out:
# [['suez', None], ['panama', None], ['cogh', 'panama', 'suez', None], ['suez', None], ['cogh', 'panama', 'suez', None], ['cogh', 'panama', 'suez', None], ['cogh', 'suez', None], ['cogh', 'suez', None], ['cogh', None], ['cogh', 'panama', None], ['cogh', 'panama', 'suez', None], ['cogh', 'panama', 'suez', None], ['panama', None], ['cogh', 'suez', None], ['suez', None], ['cogh', 'panama', 'suez', None], ['magellan-straits', 'panama', None], ['cogh', 'panama', 'suez', None], ['cogh', 'suez', None], ['cogh', 'panama', 'suez', None], ['magellan-straits', 'panama', None], ['cogh', 'panama', 'suez', None], ['cogh', 'panama', 'suez', None], ['panama', None], ['cogh', 'suez', None], ['cogh', 'panama', 'suez', None], [None], ['cogh', None], ['cogh', 'panama', 'suez', None], ['cogh', 'panama', 'suez', None], ['panama', None], ['suez', None], ['cogh', 'magellan-straits', 'panama', None], [None], ['cogh', 'suez', None], ['cogh', 'panama', 'suez', None], ['cogh', 'suez', None]]

# %%
# Print the names of each of the ports, corresponding to Route ID and availablevia details shown above
# Some of these options are currently unavailable. 
# Please refer to the Netbacks tool on the Spark Platform to check which Netbacks are currently available

print(fobPort_names)
# Out:
# ['Wheatstone', 'Woodfibre LNG', 'Corpus Christi', 'Bintulu', 'Lake Charles', 'Elba Island', 'Das Island', 'Gorgon', 'Congo LNG', 'Atlantic LNG', 'Bethioua', 'Cove Point', 'Peru LNG', 'Ras Laffan', 'Murmansk', 'Hammerfest', 'LNG Canada', 'Rio Grande LNG', 'Yamal', 'Plaquemines', 'Costa Azul', 'Altamira', 'Sabine Pass', 'Puerto Libertad', 'NWS', 'Delfin FLNG', 'Bioko', 'Bonny LNG', 'Freeport', 'Cameron (Liqu.)', 'Kamchatka', 'GLNG', 'Argentina LNG', 'Soyo', 'Qalhat', 'Calcasieu Pass', 'Tangguh']

# %%
# Shows the structure of the raw dictionary called
dicto1
# Out:
# {'staticData': {'viaPoints': [{'code': 'panama', 'name': 'Panama'},
#    {'code': 'suez', 'name': 'Suez'},
#    {'code': 'cogh', 'name': 'COGH'},
#    {'code': 'magellan-straits', 'name': 'Strait of Magellan'}],
#   'fobPorts': [{'uuid': '00398967-3ee1-4b26-bcdb-805ad19dbcce',
#     'name': 'Wheatstone',
#     'availableViaPoints': ['suez', None]},
#    {'uuid': '00314d16-eada-4f37-bff3-d844708aeb45',
#     'name': 'Woodfibre LNG',
#     'availableViaPoints': ['panama', None]},
#    {'uuid': '0030c461-9a63-403d-8f53-9327ea773517',
#     'name': 'Corpus Christi',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003342b7-ba5b-4f0e-b6df-4d95837a5691',
#     'name': 'Bintulu',
#     'availableViaPoints': ['suez', None]},
#    {'uuid': '003ff22f-77d8-413f-9997-2c6280e7c28c',
#     'name': 'Lake Charles',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '00352a22-e959-4233-b93d-d23a0da3dfed',
#     'name': 'Elba Island',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003b48e3-aedd-417c-8ea3-2d1dd434d8a9',
#     'name': 'Das Island',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '00312574-769c-4edf-9a55-362f3da20312',
#     'name': 'Gorgon',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '003349a0-0c2d-4517-bf0f-3aa7c47e3d50',
#     'name': 'Congo LNG',
#     'availableViaPoints': ['cogh', None]},
#    {'uuid': '00339787-d27c-4605-8409-e1c544820cec',
#     'name': 'Atlantic LNG',
#     'availableViaPoints': ['cogh', 'panama', None]},
#    {'uuid': '003afd77-2b63-41e4-8b7a-6d6294236d78',
#     'name': 'Bethioua',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003e8539-3a98-48fa-b35d-0ba061beea4e',
#     'name': 'Cove Point',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '00398395-a9d6-4d09-8e17-f731caf760d9',
#     'name': 'Peru LNG',
#     'availableViaPoints': ['panama', None]},
#    {'uuid': '003f9d1b-b4ad-4de9-8c8d-bd7fbcacd3df',
#     'name': 'Ras Laffan',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '003f9252-e4e3-4957-8462-36f4b61b3370',
#     'name': 'Murmansk',
#     'availableViaPoints': ['suez', None]},
#    {'uuid': '003f92ce-86d5-4d03-9761-311036c47812',
#     'name': 'Hammerfest',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '00369d3c-62db-4833-8c49-ea1a2fbb2b18',
#     'name': 'LNG Canada',
#     'availableViaPoints': ['magellan-straits', 'panama', None]},
#    {'uuid': '00383491-7e92-4b89-8b26-473fb3dcb9ed',
#     'name': 'Rio Grande LNG',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003a8724-b074-42e2-9e2f-ac3cc3e67ea4',
#     'name': 'Yamal',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '003adf4e-01b5-4680-9cd7-49613d5d0e3e',
#     'name': 'Plaquemines',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003e4ff1-6888-4d04-95e2-42e5b42ff722',
#     'name': 'Costa Azul',
#     'availableViaPoints': ['magellan-straits', 'panama', None]},
#    {'uuid': '00302863-23af-41a6-a8ec-82c703860811',
#     'name': 'Altamira',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003dec0a-ce8f-41db-8c24-4d7ef6addf70',
#     'name': 'Sabine Pass',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003ef335-be59-48ca-97aa-cf1fd8dea6fb',
#     'name': 'Puerto Libertad',
#     'availableViaPoints': ['panama', None]},
#    {'uuid': '00381c87-4180-4430-80f1-bf828099124f',
#     'name': 'NWS',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '003fa7a4-b8ff-42e7-a146-983baddc769c',
#     'name': 'Delfin FLNG',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '003e50dc-2dca-44e5-b519-c4d704c6762d',
#     'name': 'Bioko',
#     'availableViaPoints': [None]},
#    {'uuid': '0034fc9c-bb57-42b6-a91b-6f08c3795a25',
#     'name': 'Bonny LNG',
#     'availableViaPoints': ['cogh', None]},
#    {'uuid': '0039b921-cc5c-47e3-9a31-9dfb0c55d345',
#     'name': 'Freeport',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '00356046-86ab-4a76-a689-99af1b3027ad',
#     'name': 'Cameron (Liqu.)',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '0033d717-1d87-407b-94b0-3f115ecd1887',
#     'name': 'Kamchatka',
#     'availableViaPoints': ['panama', None]},
#    {'uuid': '003390dc-0918-485a-ba91-12465d2f1890',
#     'name': 'GLNG',
#     'availableViaPoints': ['suez', None]},
#    {'uuid': '0033833f-3403-4397-97e3-2ccb9aedb62c',
#     'name': 'Argentina LNG',
#     'availableViaPoints': ['cogh', 'magellan-straits', 'panama', None]},
#    {'uuid': '003bdb09-9cc9-4998-a849-0e0dce812fa7',
#     'name': 'Soyo',
#     'availableViaPoints': [None]},
#    {'uuid': '003627f4-c752-4ce4-9ae7-7ad0fa6e53ce',
#     'name': 'Qalhat',
#     'availableViaPoints': ['cogh', 'suez', None]},
#    {'uuid': '003e005e-9aeb-4e31-b44f-6f1a5d79ea67',
#     'name': 'Calcasieu Pass',
#     'availableViaPoints': ['cogh', 'panama', 'suez', None]},
#    {'uuid': '00387996-f338-4c38-abcf-3fcfd3712339',
#     'name': 'Tangguh',
#     'availableViaPoints': ['cogh', 'suez', None]}],
#   'sparkReleases': ['2025-08-14',
#    '2025-08-13',
#    '2025-08-12',
#    '2025-08-11',
#    '2025-08-08',
#    '2025-08-07',
#    '2025-08-06',
#    '2025-08-05',
#    '2025-08-04',
#    '2025-08-01',
#    '2025-07-31',
#    '2025-07-30',
#    '2025-07-29',
#    '2025-07-28',
#    '2025-07-25',
#    '2025-07-24',
#    '2025-07-23',
#    '2025-07-22',
#    '2025-07-21',
#    '2025-07-18',
#    '2025-07-17',
#    '2025-07-16',
#    '2025-07-15',
#    '2025-07-14',
#    '2025-07-11',
#    '2025-07-10',
#    '2025-07-09',
#    '2025-07-08',
#    '2025-07-07',
#    '2025-07-04',
#    '2025-07-03',
#    '2025-07-02',
#    '2025-07-01',
#    '2025-06-30',
#    '2025-06-27',
#    '2025-06-26',
#    '2025-06-25',
#    '2025-06-24',
#    '2025-06-23',
#    '2025-06-20',
#    '2025-06-19',
#    '2025-06-18',
#    '2025-06-17',
#    '2025-06-16',
#    '2025-06-13',
#    '2025-06-12',
#    '2025-06-11',
#    '2025-06-10',
#    '2025-06-09',
#    '2025-06-06',
#    '2025-06-05',
#    '2025-06-04',
#    '2025-06-03',
#    '2025-06-02',
#    '2025-05-30',
#    '2025-05-29',
#    '2025-05-28',
#    '2025-05-27',
#    '2025-05-23',
#    '2025-05-22',
#    '2025-05-21',
#    '2025-05-20',
#    '2025-05-19',
#    '2025-05-16',
#    '2025-05-15',
#    '2025-05-14',
#    '2025-05-13',
#    '2025-05-12',
#    '2025-05-09',
#    '2025-05-08',
#    '2025-05-07',
#    '2025-05-06',
#    '2025-05-02',
#    '2025-05-01',
#    '2025-04-30',
#    '2025-04-29',
#    '2025-04-28',
#    '2025-04-25',
#    '2025-04-24',
#    '2025-04-23',
#    '2025-04-22',
#    '2025-04-17',
#    '2025-04-16',
#    '2025-04-15',
#    '2025-04-14',
#    '2025-04-11',
#    '2025-04-10',
#    '2025-04-09',
#    '2025-04-08',
#    '2025-04-07',
#    '2025-04-04',
#    '2025-04-03',
#    '2025-04-02',
#    '2025-04-01',
#    '2025-03-31',
#    '2025-03-28',
#    '2025-03-27',
#    '2025-03-26',
#    '2025-03-25',
#    '2025-03-24',
#    '2025-03-21',
#    '2025-03-20',
#    '2025-03-19',
#    '2025-03-18',
#    '2025-03-17',
#    '2025-03-14',
#    '2025-03-13',
#    '2025-03-12',
#    '2025-03-11',
#    '2025-03-10',
#    '2025-03-07',
#    '2025-03-06',
#    '2025-03-05',
#    '2025-03-04',
#    '2025-03-03',
#    '2025-02-28',
#    '2025-02-27',
#    '2025-02-26',
#    '2025-02-25',
#    '2025-02-24',
#    '2025-02-21',
#    '2025-02-20',
#    '2025-02-19',
#    '2025-02-18',
#    '2025-02-17',
#    '2025-02-14',
#    '2025-02-13',
#    '2025-02-12',
#    '2025-02-11',
#    '2025-02-10',
#    '2025-02-07',
#    '2025-02-06',
#    '2025-02-05',
#    '2025-02-04',
#    '2025-02-03',
#    '2025-01-31',
#    '2025-01-30',
#    '2025-01-29',
#    '2025-01-28',
#    '2025-01-27',
#    '2025-01-24',
#    '2025-01-23',
#    '2025-01-22',
#    '2025-01-21',
#    '2025-01-20',
#    '2025-01-17',
#    '2025-01-16',
#    '2025-01-15',
#    '2025-01-14',
#    '2025-01-13',
#    '2025-01-10',
#    '2025-01-09',
#    '2025-01-08',
#    '2025-01-07',
#    '2025-01-06',
#    '2025-01-03',
#    '2025-01-02',
#    '2024-12-31',
#    '2024-12-30',
#    '2024-12-27',
#    '2024-12-24',
#    '2024-12-23',
#    '2024-12-20',
#    '2024-12-19',
#    '2024-12-18',
#    '2024-12-17',
#    '2024-12-16',
#    '2024-12-13',
#    '2024-12-12',
#    '2024-12-11',
#    '2024-12-10',
#    '2024-12-09',
#    '2024-12-06',
#    '2024-12-05',
#    '2024-12-04',
#    '2024-12-03',
#    '2024-12-02',
#    '2024-11-29',
#    '2024-11-28',
#    '2024-11-27',
#    '2024-11-26',
#    '2024-11-25',
#    '2024-11-22',
#    '2024-11-21',
#    '2024-11-20',
#    '2024-11-19',
#    '2024-11-18',
#    '2024-11-15',
#    '2024-11-14',
#    '2024-11-13',
#    '2024-11-12',
#    '2024-11-11',
#    '2024-11-08',
#    '2024-11-07',
#    '2024-11-06',
#    '2024-11-05',
#    '2024-11-04',
#    '2024-11-01',
#    '2024-10-31',
#    '2024-10-30',
#    '2024-10-29',
#    '2024-10-28',
#    '2024-10-25',
#    '2024-10-24',
#    '2024-10-23',
#    '2024-10-22',
#    '2024-10-21',
#    '2024-10-18',
#    '2024-10-17',
#    '2024-10-16',
#    '2024-10-15',
#    '2024-10-14',
#    '2024-10-11',
#    '2024-10-10',
#    '2024-10-09',
#    '2024-10-08',
#    '2024-10-07',
#    '2024-10-04',
#    '2024-10-03',
#    '2024-10-02',
#    '2024-10-01',
#    '2024-09-30',
#    '2024-09-27',
#    '2024-09-26',
#    '2024-09-25',
#    '2024-09-24',
#    '2024-09-23',
#    '2024-09-20',
#    '2024-09-19',
#    '2024-09-18',
#    '2024-09-17',
#    '2024-09-16',
#    '2024-09-13',
#    '2024-09-12',
#    '2024-09-11',
#    '2024-09-10',
#    '2024-09-09',
#    '2024-09-06',
#    '2024-09-05',
#    '2024-09-04',
#    '2024-09-03',
#    '2024-09-02',
#    '2024-08-30',
#    '2024-08-29',
#    '2024-08-28',
#    '2024-08-27',
#    '2024-08-23',
#    '2024-08-22',
#    '2024-08-21',
#    '2024-08-20',
#    '2024-08-19',
#    '2024-08-16',
#    '2024-08-15',
#    '2024-08-14',
#    '2024-08-13',
#    '2024-08-12',
#    '2024-08-09',
#    '2024-08-08',
#    '2024-08-07',
#    '2024-08-06',
#    '2024-08-05',
#    '2024-08-02',
#    '2024-08-01',
#    '2024-07-31',
#    '2024-07-30',
#    '2024-07-29',
#    '2024-07-26',
#    '2024-07-25',
#    '2024-07-24',
#    '2024-07-23',
#    '2024-07-22',
#    '2024-07-19',
#    '2024-07-18',
#    '2024-07-17',
#    '2024-07-16',
#    '2024-07-15',
#    '2024-07-12',
#    '2024-07-11',
#    '2024-07-10',
#    '2024-07-09',
#    '2024-07-08',
#    '2024-07-05',
#    '2024-07-04',
#    '2024-07-03',
#    '2024-07-02',
#    '2024-07-01',
#    '2024-06-28',
#    '2024-06-27',
#    '2024-06-26',
#    '2024-06-25',
#    '2024-06-24',
#    '2024-06-21',
#    '2024-06-20',
#    '2024-06-19',
#    '2024-06-18',
#    '2024-06-17',
#    '2024-06-14',
#    '2024-06-13',
#    '2024-06-12',
#    '2024-06-11',
#    '2024-06-10',
#    '2024-06-07',
#    '2024-06-06',
#    '2024-06-05',
#    '2024-06-04',
#    '2024-06-03',
#    '2024-05-31',
#    '2024-05-30',
#    '2024-05-29',
#    '2024-05-28',
#    '2024-05-24',
#    '2024-05-23',
#    '2024-05-22',
#    '2024-05-21',
#    '2024-05-20',
#    '2024-05-17',
#    '2024-05-16',
#    '2024-05-15',
#    '2024-05-14',
#    '2024-05-13',
#    '2024-05-10',
#    '2024-05-09',
#    '2024-05-08',
#    '2024-05-07',
#    '2024-05-03',
#    '2024-05-02',
#    '2024-05-01',
#    '2024-04-30',
#    '2024-04-29',
#    '2024-04-26',
#    '2024-04-25',
#    '2024-04-24',
#    '2024-04-23',
#    '2024-04-22',
#    '2024-04-19',
#    '2024-04-18',
#    '2024-04-17',
#    '2024-04-16',
#    '2024-04-15',
#    '2024-04-12',
#    '2024-04-11',
#    '2024-04-10',
#    '2024-04-09',
#    '2024-04-08',
#    '2024-04-05',
#    '2024-04-04',
#    '2024-04-03',
#    '2024-04-02',
#    '2024-03-28',
#    '2024-03-27',
#    '2024-03-26',
#    '2024-03-25',
#    '2024-03-22',
#    '2024-03-21',
#    '2024-03-20',
#    '2024-03-19',
#    '2024-03-18',
#    '2024-03-15',
#    '2024-03-14',
#    '2024-03-13',
#    '2024-03-12',
#    '2024-03-11',
#    '2024-03-08',
#    '2024-03-07',
#    '2024-03-06',
#    '2024-03-05',
#    '2024-03-04',
#    '2024-03-01',
#    '2024-02-29',
#    '2024-02-28',
#    '2024-02-27',
#    '2024-02-26',
#    '2024-02-23',
#    '2024-02-22',
#    '2024-02-21',
#    '2024-02-20',
#    '2024-02-19',
#    '2024-02-16',
#    '2024-02-15',
#    '2024-02-14',
#    '2024-02-13',
#    '2024-02-12',
#    '2024-02-09',
#    '2024-02-08',
#    '2024-02-07',
#    '2024-02-06',
#    '2024-02-05',
#    '2024-02-02',
#    '2024-02-01',
#    '2024-01-31',
#    '2024-01-30',
#    '2024-01-29',
#    '2024-01-26',
#    '2024-01-25',
#    '2024-01-24',
#    '2024-01-23',
#    '2024-01-22',
#    '2024-01-19',
#    '2024-01-18',
#    '2024-01-17',
#    '2024-01-16',
#    '2024-01-15',
#    '2024-01-12',
#    '2024-01-11',
#    '2024-01-10',
#    '2024-01-09',
#    '2024-01-08',
#    '2024-01-05',
#    '2024-01-04',
#    '2024-01-03',
#    '2024-01-02',
#    '2023-12-29',
#    '2023-12-28',
#    '2023-12-27',
#    '2023-12-22',
#    '2023-12-21',
#    '2023-12-20',
#    '2023-12-19',
#    '2023-12-18',
#    '2023-12-15',
#    '2023-12-14',
#    '2023-12-13',
#    '2023-12-12',
#    '2023-12-11',
#    '2023-12-08',
#    '2023-12-07',
#    '2023-12-06',
#    '2023-12-05',
#    '2023-12-04',
#    '2023-12-01',
#    '2023-11-30',
#    '2023-11-29',
#    '2023-11-28',
#    '2023-11-27',
#    '2023-11-24',
#    '2023-11-23',
#    '2023-11-22',
#    '2023-11-21',
#    '2023-11-20',
#    '2023-11-17',
#    '2023-11-16',
#    '2023-11-15',
#    '2023-11-14',
#    '2023-11-13',
#    '2023-11-10',
#    '2023-11-09',
#    '2023-11-08',
#    '2023-11-07',
#    '2023-11-06',
#    '2023-11-03',
#    '2023-11-02',
#    '2023-11-01',
#    '2023-10-31',
#    '2023-10-30',
#    '2023-10-27',
#    '2023-10-26',
#    '2023-10-25',
#    '2023-10-24',
#    '2023-10-23',
#    '2023-10-20',
#    '2023-10-19',
#    '2023-10-18',
#    '2023-10-17',
#    '2023-10-16',
#    '2023-10-13',
#    '2023-10-12',
#    '2023-10-11',
#    '2023-10-10',
#    '2023-10-09',
#    '2023-10-06',
#    '2023-10-05',
#    '2023-10-04',
#    '2023-10-03',
#    '2023-10-02',
#    '2023-09-29',
#    '2023-09-28',
#    '2023-09-27',
#    '2023-09-26',
#    '2023-09-25',
#    '2023-09-22',
#    '2023-09-21',
#    '2023-09-20',
#    '2023-09-19',
#    '2023-09-18',
#    '2023-09-15',
#    '2023-09-14',
#    '2023-09-13',
#    '2023-09-12',
#    '2023-09-11',
#    '2023-09-08',
#    '2023-09-07',
#    '2023-09-06',
#    '2023-09-05',
#    '2023-09-04',
#    '2023-09-01',
#    '2023-08-31',
#    '2023-08-30',
#    '2023-08-29',
#    '2023-08-25',
#    '2023-08-24',
#    '2023-08-23',
#    '2023-08-22',
#    '2023-08-21',
#    '2023-08-18',
#    '2023-08-17',
#    '2023-08-16',
#    '2023-08-15',
#    '2023-08-14',
#    '2023-08-11',
#    '2023-08-10',
#    '2023-08-09',
#    '2023-08-08',
#    '2023-08-07',
#    '2023-08-04',
#    '2023-08-03',
#    '2023-08-02',
#    '2023-08-01',
#    '2023-07-31',
#    '2023-07-28',
#    '2023-07-27',
#    '2023-07-26',
#    '2023-07-25',
#    '2023-07-24',
#    '2023-07-21',
#    '2023-07-20',
#    '2023-07-19',
#    '2023-07-18',
#    '2023-07-17',
#    '2023-07-14',
#    '2023-07-13',
#    '2023-07-12',
#    '2023-07-11',
#    '2023-07-10',
#    '2023-07-07',
#    '2023-07-06',
#    '2023-07-05',
#    '2023-07-04',
#    '2023-07-03',
#    '2023-06-30',
#    '2023-06-29',
#    '2023-06-28',
#    '2023-06-27',
#    '2023-06-26',
#    '2023-06-23',
#    '2023-06-22',
#    '2023-06-21',
#    '2023-06-20',
#    '2023-06-19',
#    '2023-06-16',
#    '2023-06-15',
#    '2023-06-14',
#    '2023-06-13',
#    '2023-06-12',
#    '2023-06-09',
#    '2023-06-08',
#    '2023-06-07',
#    '2023-06-06',
#    '2023-06-05',
#    '2023-06-02',
#    '2023-06-01',
#    '2023-05-31',
#    '2023-05-30',
#    '2023-05-26',
#    '2023-05-25',
#    '2023-05-24',
#    '2023-05-23',
#    '2023-05-22',
#    '2023-05-19',
#    '2023-05-18',
#    '2023-05-17',
#    '2023-05-16',
#    '2023-05-15',
#    '2023-05-12',
#    '2023-05-11',
#    '2023-05-10',
#    '2023-05-09',
#    '2023-05-05',
#    '2023-05-04',
#    '2023-05-03',
#    '2023-05-02',
#    '2023-04-28',
#    '2023-04-27',
#    '2023-04-26',
#    '2023-04-25',
#    '2023-04-24',
#    '2023-04-21',
#    '2023-04-20',
#    '2023-04-19',
#    '2023-04-18',
#    '2023-04-17',
#    '2023-04-14',
#    '2023-04-13',
#    '2023-04-12',
#    '2023-04-11',
#    '2023-04-06',
#    '2023-04-05',
#    '2023-04-04',
#    '2023-04-03',
#    '2023-03-31',
#    '2023-03-30',
#    '2023-03-29',
#    '2023-03-28',
#    '2023-03-27',
#    '2023-03-24',
#    '2023-03-23',
#    '2023-03-22',
#    '2023-03-21',
#    '2023-03-20',
#    '2023-03-17',
#    '2023-03-16',
#    '2023-03-15',
#    '2023-03-14',
#    '2023-03-13',
#    '2023-03-10',
#    '2023-03-09',
#    '2023-03-08',
#    '2023-03-07',
#    '2023-03-06',
#    '2023-03-03',
#    '2023-03-02',
#    '2023-03-01',
#    '2023-02-28',
#    '2023-02-27',
#    '2023-02-24',
#    '2023-02-23',
#    '2023-02-22',
#    '2023-02-21',
#    '2023-02-20',
#    '2023-02-17',
#    '2023-02-16',
#    '2023-02-15',
#    '2023-02-14',
#    '2023-02-13',
#    '2023-02-10',
#    '2023-02-09',
#    '2023-02-08',
#    '2023-02-07',
#    '2023-02-06',
#    '2023-02-03',
#    '2023-02-02',
#    '2023-02-01',
#    '2023-01-31',
#    '2023-01-30',
#    '2023-01-27',
#    '2023-01-26',
#    '2023-01-25',
#    '2023-01-24',
#    '2023-01-23',
#    '2023-01-20',
#    '2023-01-19',
#    '2023-01-18',
#    '2023-01-17',
#    '2023-01-16',
#    '2023-01-13',
#    '2023-01-12',
#    '2023-01-11',
#    '2023-01-10',
#    '2023-01-09',
#    '2023-01-06',
#    '2023-01-05',
#    '2023-01-04',
#    '2023-01-03',
#    '2022-12-30',
#    '2022-12-29',
#    '2022-12-28',
#    '2022-12-23',
#    '2022-12-22',
#    '2022-12-21',
#    '2022-12-20',
#    '2022-12-19',
#    '2022-12-16',
#    '2022-12-15',
#    '2022-12-14',
#    '2022-12-13',
#    '2022-12-12',
#    '2022-12-09',
#    '2022-12-08',
#    '2022-12-07',
#    '2022-12-06',
#    '2022-12-05',
#    '2022-12-02',
#    '2022-12-01',
#    '2022-11-30',
#    '2022-11-29',
#    '2022-11-28',
#    '2022-11-25',
#    '2022-11-24',
#    '2022-11-23',
#    '2022-11-22',
#    '2022-11-21',
#    '2022-11-18',
#    '2022-11-17',
#    '2022-11-16',
#    '2022-11-15',
#    '2022-11-14',
#    '2022-11-11',
#    '2022-11-10',
#    '2022-11-09',
#    '2022-11-08',
#    '2022-11-07',
#    '2022-11-04',
#    '2022-11-03',
#    '2022-11-02',
#    '2022-11-01',
#    '2022-10-31',
#    '2022-10-28',
#    '2022-10-27',
#    '2022-10-26',
#    '2022-10-25',
#    '2022-10-24',
#    '2022-10-21',
#    '2022-10-20',
#    '2022-10-19',
#    '2022-10-18',
#    '2022-10-17',
#    '2022-10-14',
#    '2022-10-13',
#    '2022-10-12',
#    '2022-10-11',
#    '2022-10-10',
#    '2022-10-07',
#    '2022-10-06',
#    '2022-10-05',
#    '2022-10-04',
#    '2022-10-03',
#    '2022-09-30',
#    '2022-09-29',
#    '2022-09-28',
#    '2022-09-27',
#    '2022-09-26',
#    '2022-09-23',
#    '2022-09-22',
#    '2022-09-21',
#    '2022-09-20',
#    '2022-09-16',
#    '2022-09-15',
#    '2022-09-14',
#    '2022-09-13',
#    '2022-09-12',
#    '2022-09-09',
#    '2022-09-08',
#    '2022-09-07',
#    '2022-09-06',
#    '2022-09-05',
#    '2022-09-02',
#    '2022-09-01',
#    '2022-08-31',
#    '2022-08-30',
#    '2022-08-26',
#    '2022-08-25',
#    '2022-08-24',
#    '2022-08-23',
#    '2022-08-22',
#    '2022-08-19',
#    '2022-08-18',
#    '2022-08-17',
#    '2022-08-16',
#    '2022-08-15',
#    '2022-08-12',
#    '2022-08-11',
#    '2022-08-10',
#    '2022-08-09',
#    '2022-08-08',
#    '2022-08-05',
#    '2022-08-04',
#    '2022-08-03',
#    '2022-08-02',
#    '2022-08-01',
#    '2022-07-29',
#    '2022-07-28',
#    '2022-07-27',
#    '2022-07-26',
#    '2022-07-25',
#    '2022-07-22',
#    '2022-07-21',
#    '2022-07-20',
#    '2022-07-19',
#    '2022-07-18',
#    '2022-07-15',
#    '2022-07-14',
#    '2022-07-13',
#    '2022-07-12',
#    '2022-07-11',
#    '2022-07-08',
#    '2022-07-07',
#    '2022-07-06',
#    '2022-07-05',
#    '2022-07-04',
#    '2022-07-01',
#    '2022-06-30',
#    '2022-06-29',
#    '2022-06-28',
#    '2022-06-27',
#    '2022-06-24',
#    '2022-06-23',
#    '2022-06-22',
#    '2022-06-21',
#    '2022-06-20',
#    '2022-06-17',
#    '2022-06-16',
#    '2022-06-15',
#    '2022-06-14',
#    '2022-06-13',
#    '2022-06-10',
#    '2022-06-09',
#    '2022-06-08',
#    '2022-06-07',
#    '2022-06-06',
#    '2022-06-01',
#    '2022-05-31',
#    '2022-05-30',
#    '2022-05-27',
#    '2022-05-26',
#    '2022-05-25',
#    '2022-05-24',
#    '2022-05-23',
#    '2022-05-20',
#    '2022-05-19',
#    '2022-05-18',
#    '2022-05-17',
#    '2022-05-16',
#    '2022-05-13',
#    '2022-05-12',
#    '2022-05-11',
#    '2022-05-10',
#    '2022-05-09',
#    '2022-05-06',
#    '2022-05-05',
#    '2022-05-04',
#    '2022-05-03',
#    '2022-04-29',
#    '2022-04-28',
#    '2022-04-27',
#    '2022-04-26',
#    '2022-04-25',
#    '2022-04-22',
#    '2022-04-21',
#    '2022-04-20',
#    '2022-04-19',
#    '2022-04-14',
#    '2022-04-13',
#    '2022-04-12',
#    '2022-04-11',
#    '2022-04-08',
#    '2022-04-07',
#    '2022-04-06',
#    '2022-04-05',
#    '2022-04-04',
#    '2022-04-01',
#    '2022-03-31',
#    '2022-03-30',
#    '2022-03-29',
#    '2022-03-28',
#    '2022-03-25',
#    '2022-03-24',
#    '2022-03-23',
#    '2022-03-22',
#    '2022-03-21',
#    '2022-03-18',
#    '2022-03-17',
#    '2022-03-16',
#    '2022-03-15',
#    '2022-03-14',
#    '2022-03-11',
#    '2022-03-10',
#    '2022-03-09',
#    '2022-03-08',
#    '2022-03-07',
#    '2022-03-04',
#    '2022-03-03',
#    '2022-03-02',
#    '2022-03-01',
#    '2022-02-28',
#    '2022-02-25',
#    '2022-02-24',
#    '2022-02-23',
#    '2022-02-22',
#    '2022-02-21',
#    '2022-02-18',
#    '2022-02-17',
#    '2022-02-16',
#    '2022-02-15',
#    '2022-02-14',
#    '2022-02-11',
#    '2022-02-10',
#    '2022-02-09',
#    '2022-02-08',
#    '2022-02-07',
#    '2022-02-04',
#    '2022-02-03',
#    '2022-02-02',
#    '2022-02-01',
#    '2022-01-31',
#    '2022-01-28',
#    '2022-01-27',
#    '2022-01-26',
#    '2022-01-25',
#    '2022-01-24',
#    '2022-01-21',
#    '2022-01-20',
#    '2022-01-19',
#    '2022-01-18',
#    '2022-01-17',
#    '2022-01-14',
#    '2022-01-13',
#    '2022-01-12',
#    '2022-01-11',
#    '2022-01-10',
#    '2022-01-07',
#    '2022-01-06',
#    '2022-01-05',
#    '2022-01-04',
#    '2021-12-30',
#    '2021-12-29',
#    '2021-12-23',
#    '2021-12-22',
#    '2021-12-21',
#    '2021-12-20',
#    '2021-12-17',
#    '2021-12-16',
#    '2021-12-15',
#    '2021-12-14',
#    '2021-12-13',
#    '2021-12-10',
#    '2021-12-09',
#    '2021-12-08',
#    '2021-12-07',
#    '2021-12-06',
#    '2021-12-03',
#    '2021-12-02',
#    '2021-12-01',
#    '2021-11-30',
#    '2021-11-29',
#    '2021-11-26',
#    '2021-11-25',
#    '2021-11-24',
#    '2021-11-23',
#    '2021-11-22',
#    '2021-11-19',
#    '2021-11-18',
#    '2021-11-17',
#    '2021-11-16',
#    '2021-11-15',
#    '2021-11-12',
#    '2021-11-11',
#    '2021-11-10',
#    '2021-11-09',
#    '2021-11-08',
#    '2021-11-05',
#    '2021-11-04',
#    '2021-11-03',
#    '2021-11-02',
#    '2021-11-01',
#    '2021-10-29',
#    '2021-10-28',
#    '2021-10-27',
#    '2021-10-26',
#    '2021-10-25',
#    '2021-10-22',
#    '2021-10-21',
#    '2021-10-20',
#    '2021-10-19',
#    '2021-10-18',
#    '2021-10-15',
#    '2021-10-14',
#    '2021-10-13',
#    '2021-10-12',
#    '2021-10-11',
#    '2021-10-08',
#    '2021-10-07',
#    '2021-10-06',
#    '2021-10-05',
#    '2021-10-04',
#    '2021-10-01',
#    '2021-09-30',
#    '2021-09-29',
#    '2021-09-28',
#    '2021-09-27',
#    '2021-09-24',
#    '2021-09-23',
#    '2021-09-22',
#    '2021-09-21',
#    '2021-09-20',
#    '2021-09-17',
#    '2021-09-16',
#    '2021-09-15',
#    '2021-09-14',
#    '2021-09-13',
#    '2021-09-10',
#    '2021-09-09',
#    '2021-09-08',
#    '2021-09-07',
#    '2021-09-06',
#    '2021-09-03',
#    '2021-09-02',
#    '2021-09-01'],
#   'ladenBallastDays': [[0, 0],
#    [1, 1],
#    [4, 4],
#    [7, 7],
#    [10, 10],
#    [15, 15],
#    [20, 20]]}}

# %% [markdown]
# ### Reformatting
#
# For a more accessible data format, we filter the data to only retrieve ports that have available Netbacks data. We then reformat this into a DataFrame.

# %%
# Define formatting data function
def format_store(available_via, fob_names, tickrs):
    dict_store = {
        "Index": [],
        "Ports": [],
        "Ticker": [],
        "Available Via": []
    }
    
    c = 0
    for a in available_via:
        ## Check which routes have non-empty Netbacks data and save indices
        if len(a) != 0:
            dict_store['Index'].append(c)

            # Use these indices to retrive the corresponding Netbacks info
            dict_store['Ports'].append(fob_names[c])
            dict_store['Ticker'].append(tickrs[c])
            dict_store['Available Via'].append(available_via[c])
        c += 1
    # Show available Netbacks ports in a DataFrame (with corresponding indices)
    dict_df = pd.DataFrame(dict_store)
    return dict_df


# Run formatting data function
available_df = format_store(availablevia,fobPort_names,tickers)

# View some of the dataframe
available_df.head()
# Out:
#    Index           Ports                                Ticker  \
# 0      0      Wheatstone  00398967-3ee1-4b26-bcdb-805ad19dbcce
# 1      1   Woodfibre LNG  00314d16-eada-4f37-bff3-d844708aeb45
# 2      2  Corpus Christi  0030c461-9a63-403d-8f53-9327ea773517
# 3      3         Bintulu  003342b7-ba5b-4f0e-b6df-4d95837a5691
# 4      4    Lake Charles  003ff22f-77d8-413f-9997-2c6280e7c28c
#
#                 Available Via
# 0                [suez, None]
# 1              [panama, None]
# 2  [cogh, panama, suez, None]
# 3                [suez, None]
# 4  [cogh, panama, suez, None]

# %% [markdown]
# ## Fetching Arb Breakevens Data specific to one port
#
# Now that we can see all the available Netbacks data available to us, we can start to define what ports we want to call Arb Breakevens data for (by referring to 'available_df' above).
#
# The first step is to choose which port ID ('my_ticker') we want. We check what possible routes are available for this port ('possible_via') and then choose one ('my_via').
#
# __This is where you should input the specific Netbacks parameters you want to see__

# %%
# Choose route ID and price release date

# Here we define which port we want
port = "Sabine Pass"
ti = int(available_df[available_df["Ports"] == port]["Index"])
my_ticker = tickers[ti]

print(my_ticker)
# Out:
# 003dec0a-ce8f-41db-8c24-4d7ef6addf70
# C:\Users\Qasim\AppData\Local\Temp\ipykernel_17728\2554701797.py:5: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   ti = int(available_df[available_df["Ports"] == port]["Index"])

# %%
# See possible route passage options
possible_via = availablevia[tickers.index(my_ticker)]
print(possible_via)
# Out:
# ['cogh', 'panama', 'suez', None]

# %%
# Choose route passage
my_via = possible_via[0]
print(my_via)
# Out:
# cogh

# %% [markdown]
# ## Data Import Function
#
# Defining functio to fetch Arb Breakevens data, as well as the data format of choice. In the fetch request, we use the URL:
#
# __uri="/v1.0/netbacks/arb-breakevens/"__
#
# We then print the output. The data function takes 6 inputs:
# - __breakeven -__  which breakeven you're looking to pull, 'jkm-ttf' or 'freight'
# - __ticker -__  which FoB port ticker to use
# - __via -__  which via point to use ('cogh', 'panama' etc.)
# - __start -__  what date you want the historical data to start from. Format in yyyy-mm-dd
# - __end -__  what date you want the historical data to end at (inclusive). Format in yyyy-mm-dd
# - __format -__ which format you'd like to output the data, 'json' or 'csv'. Metadata is only available via JSON
#
# __This function does not need to be altered by the user.__

# %%
## Defining the function
from io import StringIO

def fetch_breakevens(access_token, ticker, via=None, breakeven='jkm-ttf', start=None, end=None, format='json'):
    
    #For a route, fetch then display the route details
    #https://api.sparkcommodities.com/v1.0/netbacks/arb-breakevens/
    


    query_params = breakeven + '/' + "?fob-port={}".format(ticker)

    if via is not None:
        query_params += "&via-point={}".format(via)
    if start is not None:
        query_params += "&start={}".format(start)
    if end is not None:
        query_params += "&end={}".format(end)

    uri = "/v1.0/netbacks/arb-breakevens/{}".format(query_params)
    print(uri)
    content = do_api_get_query(
        uri="/v1.0/netbacks/arb-breakevens/{}".format(query_params),
        access_token=access_token, format=format,
    )
    
    if format == 'json':
        my_dict = content['data']
    else:
        my_dict = content.decode('utf-8')
        my_dict = pd.read_csv(StringIO(my_dict))

    return my_dict

## Calling that function and storing the output - JSON version
my_dict = fetch_breakevens(access_token, my_ticker, via='cogh', breakeven='jkm-ttf', start='2025-07-20', end='2025-07-30')
# Out:
# /v1.0/netbacks/arb-breakevens/jkm-ttf/?fob-port=003dec0a-ce8f-41db-8c24-4d7ef6addf70&via-point=cogh&start=2025-07-20&end=2025-07-30

# %%
# JSON data sample
my_dict
# Out:
# [{'releaseDate': '2025-07-30',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.159',
#     'jkmTtfSpreadBreakeven': '0.389',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.163',
#     'jkmTtfSpreadBreakeven': '0.288',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.138',
#     'jkmTtfSpreadBreakeven': '0.458',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.173',
#     'jkmTtfSpreadBreakeven': '0.598',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.353',
#     'jkmTtfSpreadBreakeven': '0.728',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.545',
#     'jkmTtfSpreadBreakeven': '0.72',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.479',
#     'jkmTtfSpreadBreakeven': '0.64',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.208',
#     'jkmTtfSpreadBreakeven': '0.487',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '-0.022',
#     'jkmTtfSpreadBreakeven': '0.332',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-29',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.158',
#     'jkmTtfSpreadBreakeven': '0.383',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.167',
#     'jkmTtfSpreadBreakeven': '0.267',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.13',
#     'jkmTtfSpreadBreakeven': '0.43',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.146',
#     'jkmTtfSpreadBreakeven': '0.596',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.326',
#     'jkmTtfSpreadBreakeven': '0.751',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.521',
#     'jkmTtfSpreadBreakeven': '0.696',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.454',
#     'jkmTtfSpreadBreakeven': '0.629',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.183',
#     'jkmTtfSpreadBreakeven': '0.483',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '0.005',
#     'jkmTtfSpreadBreakeven': '0.33',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-28',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.091',
#     'jkmTtfSpreadBreakeven': '0.366',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.092',
#     'jkmTtfSpreadBreakeven': '0.242',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.078',
#     'jkmTtfSpreadBreakeven': '0.428',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.12',
#     'jkmTtfSpreadBreakeven': '0.595',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.303',
#     'jkmTtfSpreadBreakeven': '0.753',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.483',
#     'jkmTtfSpreadBreakeven': '0.683',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.423',
#     'jkmTtfSpreadBreakeven': '0.613',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.18',
#     'jkmTtfSpreadBreakeven': '0.48',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '-0.001',
#     'jkmTtfSpreadBreakeven': '0.336',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-25',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.104',
#     'jkmTtfSpreadBreakeven': '0.374',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.121',
#     'jkmTtfSpreadBreakeven': '0.246',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.104',
#     'jkmTtfSpreadBreakeven': '0.384',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.14',
#     'jkmTtfSpreadBreakeven': '0.615',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.329',
#     'jkmTtfSpreadBreakeven': '0.754',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.5',
#     'jkmTtfSpreadBreakeven': '0.65',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.419',
#     'jkmTtfSpreadBreakeven': '0.607',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.169',
#     'jkmTtfSpreadBreakeven': '0.468',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '0.006',
#     'jkmTtfSpreadBreakeven': '0.331',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-24',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.137',
#     'jkmTtfSpreadBreakeven': '0.362',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.132',
#     'jkmTtfSpreadBreakeven': '0.232',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.109',
#     'jkmTtfSpreadBreakeven': '0.384',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.138',
#     'jkmTtfSpreadBreakeven': '0.588',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.312',
#     'jkmTtfSpreadBreakeven': '0.737',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.48',
#     'jkmTtfSpreadBreakeven': '0.655',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.411',
#     'jkmTtfSpreadBreakeven': '0.611',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.17',
#     'jkmTtfSpreadBreakeven': '0.473',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '0.004',
#     'jkmTtfSpreadBreakeven': '0.333',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-23',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.226',
#     'jkmTtfSpreadBreakeven': '0.416',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.22',
#     'jkmTtfSpreadBreakeven': '0.295',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.18',
#     'jkmTtfSpreadBreakeven': '0.505',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.199',
#     'jkmTtfSpreadBreakeven': '0.649',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.356',
#     'jkmTtfSpreadBreakeven': '0.781',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.516',
#     'jkmTtfSpreadBreakeven': '0.691',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.437',
#     'jkmTtfSpreadBreakeven': '0.612',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.185',
#     'jkmTtfSpreadBreakeven': '0.493',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '-0.021',
#     'jkmTtfSpreadBreakeven': '0.363',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-22',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.25',
#     'jkmTtfSpreadBreakeven': '0.5',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.29',
#     'jkmTtfSpreadBreakeven': '0.44',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.278',
#     'jkmTtfSpreadBreakeven': '0.628',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.263',
#     'jkmTtfSpreadBreakeven': '0.728',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.358',
#     'jkmTtfSpreadBreakeven': '0.794',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.506',
#     'jkmTtfSpreadBreakeven': '0.731',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.44',
#     'jkmTtfSpreadBreakeven': '0.633',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.19',
#     'jkmTtfSpreadBreakeven': '0.489',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '-0.014',
#     'jkmTtfSpreadBreakeven': '0.347',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]},
#  {'releaseDate': '2025-07-21',
#   'prices': [{'deliveryMonthIndex': 'M+2',
#     'deliveryMonthStart': '2025-09',
#     'deliveryMonthArb': None,
#     'jkmTtfSpreadBreakeven': None,
#     'deliveryDate': '2025-09-15',
#     'nweCargoLoadDate': '2025-08-29',
#     'neaCargoLoadDate': '2025-08-02'},
#    {'deliveryMonthIndex': 'M+3',
#     'deliveryMonthStart': '2025-10',
#     'deliveryMonthArb': '-0.267',
#     'jkmTtfSpreadBreakeven': '0.492',
#     'deliveryDate': '2025-10-15',
#     'nweCargoLoadDate': '2025-09-28',
#     'neaCargoLoadDate': '2025-09-01'},
#    {'deliveryMonthIndex': 'M+4',
#     'deliveryMonthStart': '2025-11',
#     'deliveryMonthArb': '-0.298',
#     'jkmTtfSpreadBreakeven': '0.453',
#     'deliveryDate': '2025-11-15',
#     'nweCargoLoadDate': '2025-10-29',
#     'neaCargoLoadDate': '2025-10-02'},
#    {'deliveryMonthIndex': 'M+5',
#     'deliveryMonthStart': '2025-12',
#     'deliveryMonthArb': '-0.291',
#     'jkmTtfSpreadBreakeven': '0.641',
#     'deliveryDate': '2025-12-15',
#     'nweCargoLoadDate': '2025-11-28',
#     'neaCargoLoadDate': '2025-11-01'},
#    {'deliveryMonthIndex': 'M+6',
#     'deliveryMonthStart': '2026-01',
#     'deliveryMonthArb': '-0.285',
#     'jkmTtfSpreadBreakeven': '0.737',
#     'deliveryDate': '2026-01-15',
#     'nweCargoLoadDate': '2025-12-29',
#     'neaCargoLoadDate': '2025-12-02'},
#    {'deliveryMonthIndex': 'M+7',
#     'deliveryMonthStart': '2026-02',
#     'deliveryMonthArb': '-0.395',
#     'jkmTtfSpreadBreakeven': '0.818',
#     'deliveryDate': '2026-02-15',
#     'nweCargoLoadDate': '2026-01-29',
#     'neaCargoLoadDate': '2026-01-02'},
#    {'deliveryMonthIndex': 'M+8',
#     'deliveryMonthStart': '2026-03',
#     'deliveryMonthArb': '-0.548',
#     'jkmTtfSpreadBreakeven': '0.723',
#     'deliveryDate': '2026-03-15',
#     'nweCargoLoadDate': '2026-02-26',
#     'neaCargoLoadDate': '2026-01-30'},
#    {'deliveryMonthIndex': 'M+9',
#     'deliveryMonthStart': '2026-04',
#     'deliveryMonthArb': '-0.48',
#     'jkmTtfSpreadBreakeven': '0.643',
#     'deliveryDate': '2026-04-15',
#     'nweCargoLoadDate': '2026-03-29',
#     'neaCargoLoadDate': '2026-03-02'},
#    {'deliveryMonthIndex': 'M+10',
#     'deliveryMonthStart': '2026-05',
#     'deliveryMonthArb': '-0.221',
#     'jkmTtfSpreadBreakeven': '0.498',
#     'deliveryDate': '2026-05-15',
#     'nweCargoLoadDate': '2026-04-28',
#     'neaCargoLoadDate': '2026-04-01'},
#    {'deliveryMonthIndex': 'M+11',
#     'deliveryMonthStart': '2026-06',
#     'deliveryMonthArb': '-0.028',
#     'jkmTtfSpreadBreakeven': '0.348',
#     'deliveryDate': '2026-06-15',
#     'nweCargoLoadDate': '2026-05-29',
#     'neaCargoLoadDate': '2026-05-02'}]}]

# %% [markdown]
# ## CSV example

# %%
# calling the same data in CSV format. This option automatically converts the data to a pandas dataframe.
df = fetch_breakevens(access_token, my_ticker, via='cogh', breakeven='jkm-ttf', start='2025-07-20', end='2025-07-30', format='csv')
# Out:
# /v1.0/netbacks/arb-breakevens/jkm-ttf/?fob-port=003dec0a-ce8f-41db-8c24-4d7ef6addf70&via-point=cogh&start=2025-07-20&end=2025-07-30

# %%
# CSV data sample as a Pandas DataFrame
df
# Out:
#    ReleaseDate DeliveryMonthIndex DeliveryMonthStart DeliveryDate  \
# 0   2025-07-30                M+2            2025-09   2025-09-15
# 1   2025-07-30                M+3            2025-10   2025-10-15
# 2   2025-07-30                M+4            2025-11   2025-11-15
# 3   2025-07-30                M+5            2025-12   2025-12-15
# 4   2025-07-30                M+6            2026-01   2026-01-15
# ..         ...                ...                ...          ...
# 75  2025-07-21                M+7            2026-02   2026-02-15
# 76  2025-07-21                M+8            2026-03   2026-03-15
# 77  2025-07-21                M+9            2026-04   2026-04-15
# 78  2025-07-21               M+10            2026-05   2026-05-15
# 79  2025-07-21               M+11            2026-06   2026-06-15
#
#    NWECargoLoadDate NEACargoLoadDate  DeliveryMonthArb  JKMTTFSpreadBreakeven  \
# 0        2025-08-29       2025-08-02               NaN                    NaN
# 1        2025-09-28       2025-09-01            -0.159                  0.389
# 2        2025-10-29       2025-10-02            -0.163                  0.288
# 3        2025-11-28       2025-11-01            -0.138                  0.458
# 4        2025-12-29       2025-12-02            -0.173                  0.598
# ..              ...              ...               ...                    ...
# 75       2026-01-29       2026-01-02            -0.395                  0.818
# 76       2026-02-26       2026-01-30            -0.548                  0.723
# 77       2026-03-29       2026-03-02            -0.480                  0.643
# 78       2026-04-28       2026-04-01            -0.221                  0.498
# 79       2026-05-29       2026-05-02            -0.028                  0.348
#
#                              FobPortUUID  FobPortName ViaPoint
# 0   003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 1   003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 2   003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 3   003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 4   003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# ..                                   ...          ...      ...
# 75  003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 76  003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 77  003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 78  003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
# 79  003dec0a-ce8f-41db-8c24-4d7ef6addf70  sabine-pass     cogh
#
# [80 rows x 11 columns]
